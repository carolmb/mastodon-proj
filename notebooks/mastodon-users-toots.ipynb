# %%
import time
import glob
import json
import os.path
import requests
import pandas as pd
from  datetime import date

# %%
today = date.today()

# %%
files = glob.glob('../data/users_followers_*_2023-05-02.csv')
all_users = []
for file in files:
    users = pd.read_csv(file, sep='\t', names=['user', 'instance', 'followers', 'field'], encoding_errors='replace', on_bad_lines='warn')
    all_users.append(users)

all_users = pd.concat(all_users)
print(all_users.head())
# Out:
# Skipping line 50: expected 4 fields, saw 5
#                user            instance
# 0           rheinze        assemblag.es  \
# 1          BrianJAP      mastodon.world
# 2       joelglasman     fediscience.org
# 3  brenton_peterson     sciences.social
# 4            keremd  social.anoxinon.de
#
#                                            followers            field
# 0  [109417147220906349, 109243458234695495, 10924...  African Studies
# 1  [1302832, 110023631275744313, 1099309840163259...  African Studies
# 2                                                 []  African Studies
# 3  [107192220324249637, 109354941450990518, 10951...  African Studies
# 4  [1302832, 109212672053987101, 1092459114371518...  African Studies

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)


def get_userid(user_name, user_server, token_access):
    try:
        url = 'https://{}/api/v1/accounts/lookup/'.format(user_server)
        headers = {
            'Authorization' : 'Bearer {}'.format(token_access)
        }
        params = {
            'acct' : '{}@{}'.format(user_name, user_server)
        }
        r = session.get(url, headers=headers, params=params)

        user = json.loads(r.text)
        if 'id' in user:
            return user["id"]
        elif 'user' in user:
            return user["user"]
    except Exception as error:
        print(error)
        return None

# %%
# mastodon_app = "acmbrito_app_python_secret"
# client_id, client_secret, access_token, api_base_url = open(mastodon_app).read().split()

# %%
date_limit = date(2022, 9, 1)

# %%
import util
def get_instance_token(instance):
    return util.get_instance_token(instance)

# %%
# toots

# source to collect user toots: https://jrashford.com/2023/02/13/how-to-scrape-mastodon-timelines-using-python-and-pandas/
# API code: https://mastodonpy.readthedocs.io/en/1.8.1/_modules/mastodon/timeline.html?highlight=users%20in%20a%20given%20list
# https://docs.joinmastodon.org/methods/search/#v1

def user_toots(instance, user_id, access_token):
    URL = 'https://{}/api/v1/accounts/{}/statuses'.format(instance, user_id)
    user_toots = []
    if access_token:
        headers = {
            'Authorization' : 'Bearer {}'.format(access_token)
        }
        
        user_toots = []
        params = {}
        while True:
            #time.sleep(1)
            r = requests.get(URL, headers=headers, params=params, timeout=60)
            toots = json.loads(r.text)
            user_toots += toots
            if len(toots) == 0:
                break
            if 'error' in toots:
                print(user_id, toots)
                break
            max_id = toots[-1]['id']
            params = {'max_id' : max_id}
            
            date_str = toots[-1]['created_at'].split('T')[0]
            last_date = date.fromisoformat(date_str)
            if last_date < date_limit:
                break

    return user_toots

# %%
valid_fields = ['id',
'created_at',
'in_reply_to_account_id',
'uri',
'replies_count',
'reblogs_count',
'favourites_count',
'content'
]

# %%
files = glob.glob('temp/users_toots_2023-0*.tsv')
users_already_collected = []
invalid_users = set()
for file in files:
    invalid_users |= set(pd.read_csv(file, sep='\t')['user_id'])

print(len(invalid_users))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[9], line 5
#       3 invalid_users = set()
#       4 for file in files:
# ----> 5     invalid_users |= set(pd.read_csv(file, sep='\t')['user_id'])
#       7 print(len(invalid_users))
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\io\parsers\readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\_libs\parsers.pyx:812, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\_libs\parsers.pyx:873, in pandas._libs.parsers.TextReader._read_rows()
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\_libs\parsers.pyx:848, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\_libs\parsers.pyx:859, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File d:\Documentos\yy-projects\mastodon-proj\.venv\Lib\site-packages\pandas\_libs\parsers.pyx:2025, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
outputs = []
size = 0
user_id_map = pd.read_csv('user_id_list.tsv', sep='\t')
user_id_map = user_id_map.drop_duplicates(subset=['user', 'instance'])
user_id_map = user_id_map.dropna()

for _, user in all_users.iterrows():
    
    user_id = user_id_map[(user_id_map['user'] == user['user']) & (user_id_map['instance'] == user['instance'])]
    if len(user_id) >= 1:
        user_id = user_id['user_id'].values[0]
    
    else:
        continue

    if not user_id:
        print(user)
        continue

    if not user_id.isnumeric():
        continue

    if int(user_id) in invalid_users:
        continue
    
    instance_token = get_instance_token(user['instance'])
    if not instance_token:
        continue

    toots = user_toots(user['instance'], user_id, instance_token)
    if len(toots) > 0:
        toots_pd = pd.json_normalize(toots)
        toots_pd = toots_pd.loc[:, valid_fields]
        toots_pd['user_id'] = user_id
        size += len(toots_pd)
        outputs.append(toots_pd)

    if size > 10000:
        data_toots = pd.concat(outputs)
        data_toots.to_csv('temp/users_toots_{}_{}.tsv'.format(today, user_id), sep='\t')
        outputs = []
        size = 0

data_toots = pd.concat(outputs)
data_toots.to_csv('temp/users_toots_{}_{}.tsv'.format(today, user_id), sep='\t')

# %%
#TODO to select instances related to scholars/science
#questions: search for scholars on mastodon.social? (the "main" instance)

# o tamanho de um subconjunto para selecionar?????
# fediscience (onde todos os usuarios sao academicos) como primeiro subset
# como expandir isso para o mais instancias?
#

# %%
ids = []
i = 0
'''
for _, user in all_users.iterrows():
    instance_token = get_instance_token(user['instance'])
    user_id = get_userid(user['user'], user['instance'], instance_token)
    ids.append((user['user'], user['instance'], user_id))
    i += 1
    if i % 300 == 0:
        print(i, end='\r')
        pd.DataFrame(ids, columns=['user', 'instance', 'user_id']).to_csv('user_id_list.tsv', sep='\t')
'''

# %%
filename = '../data/mastodon_users_wOpenAlex.csv'
openalex_masto = pd.read_csv(filename, sep=',')
print(openalex_masto.columns)
openalex_masto = openalex_masto.drop(columns='Unnamed: 0').drop_duplicates()
print(openalex_masto.size)
openalex_masto.head()
# Out:
# Index(['Unnamed: 0', 'mastodon_name'], dtype='object')
# 4677
#                     mastodon_name
# 0  @HelmutBuergmann@mstdn.science
# 1           @boshek@fosstodon.org
# 2            @DenisDuboule@mas.to
# 3       @paulgkeil@mastodon.world
# 4              @rider_jon@zirk.us

# %%
ids = []
i = 0

for _, user in openalex_masto.iterrows():
    mastodon_name = user['mastodon_name'].split("@")[1:]
    user_name = mastodon_name[0]
    instance_name = mastodon_name[1]
    instance_token = get_instance_token(instance_name)
    user_id = get_userid(user_name, instance_name, instance_token)
    ids.append((user_name, instance_name, user_id))
    i += 1
    if i % 100 == 0:
        print(i, end='\r')
        pd.DataFrame(ids, columns=['user', 'instance', 'user_id']).to_csv('user111_id_list_kunilist_{}.tsv'.format(today), sep='\t')
# Out:
# HTTPSConnectionPool(host='fediscience.com', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=crisvanhout%40fediscience.com (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F3840150>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastodon.soc', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=siruiwan%40mastodon.soc (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F37C6DD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mstdn.scien', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=KeyesDiscovery%40mstdn.scien (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F384F150>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='archeo.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=francescokar%40archeo.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F38522D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=fasbrock%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F3868210>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=elinlb%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F384B010>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='sigmoid.soci', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=atchechmedjiev%40sigmoid.soci (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F3869CD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastodon.se', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=johanlinaker%40mastodon.se (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1002)')))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastodon.science', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=mjfave%40mastodon.science (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F388CFD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=Teggy%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F388EB50>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='cryoem.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=susan_lea%40cryoem.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F388C110>, 'Connection to cryoem.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='sbfa.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=minabionta%40sbfa.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F388EF50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=arne%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F389C290>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=MRITobi%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F389D2D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=jmuncke%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38800D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=trinesy%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38A92D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='social.secret', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=lars%40social.secret (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F38A92D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastodon.se', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=MartinHedberg%40mastodon.se (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1002)')))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastdn.science', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=mattloose%40mastdn.science (Caused by SSLError(SSLError(1, '[SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1002)')))
# HTTPSConnectionPool(host='social.bau', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=aurelvr%40social.bau (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F38C9410>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=KevinReuning%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38C9110>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='fediscience.o', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=cconrymurray%40fediscience.o (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F388EA50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=Claireyjaner%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38405D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=jiatruong%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38B9790>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mstdn.ai', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=fjlacueva%40mstdn.ai (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F379D710>, 'Connection to mstdn.ai timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='mastodon.aus', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=phillipscate%40mastodon.aus (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F37C4510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastadon.energy.', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=donal%40mastadon.energy. (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F37C4D50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=sreenathpaleri%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38B84D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=NickCarnes%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38D9590>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=rgomez%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38945D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='mastadon.energy', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=JustinGundlach%40mastadon.energy (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F48B4590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastodon.soci', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=ana_ines_langer%40mastodon.soci (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F48B8310>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=jlangemeyer%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F38ADD10>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='ecovo.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=erik_postma%40ecovo.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F38D8CD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastadon.scot', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=sasM%40mastadon.scot (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F48C0C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='evoeco.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=LuciKirkpatrick%40evoeco.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F48BA010>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='ecoevol.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=RyanGutenkunst%40ecoevol.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F48CF090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastodon.c.im', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=KimNossal%40mastodon.c.im (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F48CF7D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='eco.evo.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=kath_baldock%40eco.evo.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49AD7D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 4 (char 3)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mstdn.soc', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=barbarianlibra%40mstdn.soc (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49BFC50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='evoeco.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=christopher_krieg%40evoeco.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49CCD10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='m.wolfwater.com', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=librarianmer%40m.wolfwater.com (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1002)')))
# HTTPSConnectionPool(host='m.sclo.nl', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=kimdejong_psychres%40m.sclo.nl (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49D2390>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed'))
# HTTPSConnectionPool(host='mstdn.s', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=ChiaraGamberi%40mstdn.s (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49E0090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='fedisciencience.org', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=LarissaGoulart%40fedisciencience.org (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49D3990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=steffi_nolte%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F49C56D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='mastodon.ai', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=shivakjolad%40mastodon.ai (Caused by ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastodon.se', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=simonelsasser%40mastodon.se (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1002)')))
# HTTPSConnectionPool(host='other.nl', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=EricvanHeck%40other.nl (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49E2F50>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='m.sclo.nl', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=christinaisakoglou%40m.sclo.nl (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A09590>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastodon.uk', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=ela%40mastodon.uk (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate (_ssl.c:1002)')))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=Lenafrescamente%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F4A04410>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='sciences.soc.', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=plieninger%40sciences.soc. (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A27990>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=elizabethlorenc%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F49F7B10>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='mastdodon.online', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=RenseC%40mastdodon.online (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A2E250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastadon.nz', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=suzewilsonnz%40mastadon.nz (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A30110>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='ecoevol.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=JasonIsotopes%40ecoevol.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A30A10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='social.e', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=aszulinska%40social.e (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F49F7DD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='mastodin.sdf', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=greenwoodtree%40mastodin.sdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A24690>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='fedicience.org', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=GWeindel%40fedicience.org (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A404D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='twitter.tld', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=MEecoprof%40twitter.tld (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A4EF10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=idelazaro%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F4A527D0>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mathsodon.xyz.', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=Haharrington%40mathsodon.xyz. (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A5C310>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='ecoevo.soc', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=kaylakolff%40ecoevo.soc (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A5DC90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=ProfDCotton%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F4A46910>, 'Connection to home.social timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='mastadon.nz', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=RKPriestley%40mastadon.nz (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A6DC10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='scicomm.cuz', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=tinyfrozenproteins%40scicomm.cuz (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A50390>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=clevitan%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F4A41790>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='mastadon.world', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=kayrihavens%40mastadon.world (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A75B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='evoevo.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=MagdaChara%40evoevo.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A46C90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='genomics.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=vijay%40genomics.social (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A7E190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# HTTPSConnectionPool(host='maston.world', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=ekupers%40maston.world (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000263F4A79410>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='weburbanists.com', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=nlowe%40weburbanists.com (Caused by SSLError(CertificateError("hostname 'weburbanists.com' doesn't match '139.59.100.39'")))
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=amandatatts%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F4A77B90>, 'Connection to home.social timed out. (connect timeout=None)'))
# Expecting value: line 1 column 1 (char 0)
# HTTPSConnectionPool(host='home.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=mptouzel%40home.social (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000263F4A7EAD0>, 'Connection to home.social timed out. (connect timeout=None)'))

# %%
outputs = []
size = 0
user_id_map = pd.read_csv('user111_id_list_kunilist_2023-06-30.tsv', sep='\t', dtype=object)
user_id_map = user_id_map.drop_duplicates(subset=['user', 'instance'])
user_id_map = user_id_map.dropna()
#user_id_map = user_id_map.astype({'user_id':'int'})
print(user_id_map.head())

for _, user in user_id_map.iterrows():
    '''print(user)
    item = user['mastodon_name'].split('@')
    
    user = {
        'user': item[1],
        'instance': item[2]
    }'''

    user_id = user_id_map[(user_id_map['user'] == user['user']) & (user_id_map['instance'] == user['instance'])]
    if len(user_id) >= 1:
        user_id = user_id['user_id'].values[0]
    else:
        continue

    if not user_id:
        print(user)
        continue

    if not user_id.isnumeric():
        continue

    # if int(user_id) in invalid_users:
    #    continue
    
    instance_token = get_instance_token(user['instance'])
    if not instance_token:
        continue

    toots = user_toots(user['instance'], user_id, instance_token)
    if len(toots) > 0:
        toots_pd = pd.json_normalize(toots)
        toots_pd = toots_pd.loc[:, valid_fields]
        toots_pd['mastodon_name'] = "{}@{}".format(user['user'], user['instance']) 
        size += len(toots_pd)
        outputs.append(toots_pd)

    if size > 10000:
        data_toots = pd.concat(outputs)
        data_toots.to_csv('temp/users_toots_{}_{}.tsv'.format(today, user_id), sep='\t')
        outputs = []
        size = 0

data_toots = pd.concat(outputs)
data_toots.to_csv('temp/users_toots_openalex_{}_{}.tsv'.format(today, user_id), sep='\t')
# Out:
#   Unnamed: 0             user        instance             user_id
# 0          0  HelmutBuergmann   mstdn.science  109290116551935157
# 1          1           boshek   fosstodon.org  109314764090379220
# 2          2     DenisDuboule          mas.to  109258593858933399
# 3          3        paulgkeil  mastodon.world  109500238977329432
# 4          4        rider_jon         zirk.us  109365280591812662
# 108231873383230758 {'error': 'Too many requests'}
# 109252294337269013 {'error': 'Too many requests'}
# 108194402925670785 {'error': 'Too many requests'}
# 312200 {'error': 'Too many requests'}
# 109219602453681496 {'error': 'Too many requests'}
# 109394770510287303 {'error': 'Too many requests'}
# 109244312739228432 {'error': 'Too many requests'}
# 109242396345555512 {'error': 'Too many requests'}
# 108147588127310893 {'error': 'Too many requests'}
# 109248233331530003 {'error': 'Too many requests'}
# 109246123143382012 {'error': 'Too many requests'}
# 109253527096086364 {'error': 'Too many requests'}
# 109372455265699080 {'error': 'Too many requests'}
# 108243570755984490 {'error': 'Too many requests'}
# 270477 {'error': 'Too many requests'}
# 109507760362989414 {'error': 'Too many requests'}
# 109244805624994299 {'error': 'Too many requests'}
# 109490818700975658 {'error': 'Too many requests'}
# 501778 {'error': 'Too many requests'}
# 109258998835390295 {'error': 'Too many requests'}
# 109258550215514313 {'error': 'Too many requests'}
# 109259641320536546 {'error': 'Too many requests'}
# 109248578238524021 {'error': 'Too many requests'}
# 109244105436522718 {'error': 'Too many requests'}
# 140032 {'error': 'Too many requests'}
# 108197573347318141 {'error': 'Too many requests'}
# 108220094526127332 {'error': 'Too many requests'}
# 109246439898736261 {'error': 'Too many requests'}
# 109250552347203385 {'error': 'Too many requests'}
# 1036092 {'error': 'Too many requests'}
# 109251716106943694 {'error': 'Too many requests'}
# 109246059349034462 {'error': 'Too many requests'}
# 109243926293123176 {'error': 'Too many requests'}
# 109259394851576600 {'error': 'Too many requests'}
# 109244618707098765 {'error': 'Too many requests'}
# 109258754451069494 {'error': 'Too many requests'}
# 109255250825869101 {'error': 'Too many requests'}
# 109356090092829726 {'error': 'Too many requests'}
# 235265 {'error': 'Too many requests'}
# 363081 {'error': 'Too many requests'}
# 109208864689604784 {'error': 'Too many requests'}
# 109501199581089749 {'error': 'Too many requests'}
# 109245498416217369 {'error': 'Too many requests'}
# 109362755962378897 {'error': 'Too many requests'}
# 109256445893161075 {'error': 'Too many requests'}
# 109521040564771632 {'error': 'Too many requests'}
# 108197382645989378 {'error': 'Too many requests'}
# 109303621650239942 {'error': 'Too many requests'}
# 503899 {'error': 'Too many requests'}
# 109256535372745343 {'error': 'Too many requests'}
# 491408 {'error': 'Too many requests'}
# 110063187631542285 {'error': 'Too many requests'}
# 108226047470629337 {'error': 'Too many requests'}
# 109245538719694783 {'error': 'Too many requests'}
# 109243388372609150 {'error': 'Too many requests'}
# 109258902341814111 {'error': 'Too many requests'}
# 267944 {'error': 'Too many requests'}
# 37870 {'error': 'Too many requests'}
# 109240273071387835 {'error': 'Too many requests'}
# 109498718146874225 {'error': 'Too many requests'}
# 108245723457268935 {'error': 'Too many requests'}
# 109245369273162229 {'error': 'Too many requests'}
# 108245878016606881 {'error': 'Too many requests'}
# 109242076377424783 {'error': 'Too many requests'}
# 109247807171271369 {'error': 'Too many requests'}
# 109258222978707995 {'error': 'Too many requests'}
# 109246422295487569 {'error': 'Too many requests'}
# 109331776093990272 {'error': 'Too many requests'}
# 15827 {'error': 'Too many requests'}
# 109247432104710610 {'error': 'Too many requests'}
# 109252975695909094 {'error': 'Too many requests'}
# 964265 {'error': 'Too many requests'}
# 109251841864031096 {'error': 'Too many requests'}
# 109312235118077698 {'error': 'Too many requests'}
# 109255969345398096 {'error': 'Too many requests'}
# 108269301093121738 {'error': 'Too many requests'}
# 109898024678328695 {'error': 'Too many requests'}
# 109326729049085482 {'error': 'Too many requests'}
# 108304898201619124 {'error': 'Too many requests'}
# 109243800756872766 {'error': 'Too many requests'}
# 667194 {'error': 'Too many requests'}
# 110225988398635573 {'error': 'Too many requests'}

# %%
data_toots.to_csv('temp/users_toots_openalex_{}_{}.tsv'.format(today, 'last'), sep='\t')

# %%
user_id
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, user, instance, user_id]
# Index: []

# %%
access_token = get_instance_token('home.social')
user_id = get_userid('fasbrock', 'home.social', access_token)
user_toots('home.social', user_id, access_token)

# %%
print(user_id)
