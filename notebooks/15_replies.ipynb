# %%
import pandas as pd

# %%
data = pd.read_csv('toots_kuni_list.tsv', sep='\t')
data.head()
# Out:
#    Unnamed: 0            id                created_at  in_reply_to_account_id  \
# 0           0  1.105479e+17  2023-06-15T11:12:00.221Z                     NaN
# 1           1  1.098651e+17  2023-02-14T20:53:58.680Z                     NaN
# 2           2  1.098651e+17  2023-02-14T20:51:00.433Z                     NaN
# 3           3  1.098221e+17  2023-02-07T06:40:49.087Z                     NaN
# 4           4  1.098066e+17  2023-02-04T13:05:53.396Z                     NaN
#
#                                                  uri  replies_count  \
# 0  https://mastodon.green/users/DrAnaQueiros/stat...            0.0
# 1  https://mastodon.green/users/DrAnaQueiros/stat...            0.0
# 2  https://mastodon.green/users/DrAnaQueiros/stat...            0.0
# 3  https://mastodon.green/users/DrAnaQueiros/stat...            0.0
# 4  https://mastodon.green/users/DrAnaQueiros/stat...            0.0
#
#    reblogs_count  favourites_count content                mastodon_name
# 0            0.0               0.0     NaN  DrAnaQueiros@mastodon.green
# 1            0.0               0.0     NaN  DrAnaQueiros@mastodon.green
# 2            0.0               0.0     NaN  DrAnaQueiros@mastodon.green
# 3            0.0               0.0     NaN  DrAnaQueiros@mastodon.green
# 4            0.0               0.0     NaN  DrAnaQueiros@mastodon.green

# %%
data = data.dropna(subset='in_reply_to_account_id')
data.head()
# Out:
#     Unnamed: 0            id                created_at  \
# 20           6  1.093818e+17  2022-11-21T12:41:34.053Z
# 21           7  1.093818e+17  2022-11-21T12:40:53.330Z
# 22           8  1.093817e+17  2022-11-21T12:12:50.054Z
# 23           9  1.093817e+17  2022-11-21T11:57:13.909Z
# 24          10  1.093813e+17  2022-11-21T10:26:37.443Z
#
#     in_reply_to_account_id                                                uri  \
# 20            1.093662e+17  https://fediscience.org/users/macaskillaf/stat...
# 21            1.093662e+17  https://fediscience.org/users/macaskillaf/stat...
# 22            1.093010e+17  https://fediscience.org/users/macaskillaf/stat...
# 23            1.093758e+17  https://fediscience.org/users/macaskillaf/stat...
# 24            1.093758e+17  https://fediscience.org/users/macaskillaf/stat...
#
#     replies_count  reblogs_count  favourites_count  \
# 20            1.0            0.0               2.0
# 21            1.0            0.0               1.0
# 22            0.0            0.0               0.0
# 23            1.0            0.0               2.0
# 24            1.0            0.0               0.0
#
#                                               content  \
# 20  <p><span class="h-card"><a href="https://scien...
# 21  <p><span class="h-card"><a href="https://scien...
# 22  <p><span class="h-card"><a href="https://masto...
# 23  <p><span class="h-card"><a href="https://masto...
# 24  <p><span class="h-card"><a href="https://masto...
#
#                   mastodon_name
# 20  macaskillaf@fediscience.org
# 21  macaskillaf@fediscience.org
# 22  macaskillaf@fediscience.org
# 23  macaskillaf@fediscience.org
# 24  macaskillaf@fediscience.org

# %%
data = data.astype({'id':'int64', 'in_reply_to_account_id':'int64'})

# %%
data.head()
# Out:
#     Unnamed: 0                  id                created_at  \
# 20           6  109381844602271088  2022-11-21T12:41:34.053Z
# 21           7  109381841933547984  2022-11-21T12:40:53.330Z
# 22           8  109381731618334000  2022-11-21T12:12:50.054Z
# 23           9  109381670267029392  2022-11-21T11:57:13.909Z
# 24          10  109381313982669504  2022-11-21T10:26:37.443Z
#
#     in_reply_to_account_id                                                uri  \
# 20      109366168383810608  https://fediscience.org/users/macaskillaf/stat...
# 21      109366168383810608  https://fediscience.org/users/macaskillaf/stat...
# 22      109300967182789264  https://fediscience.org/users/macaskillaf/stat...
# 23      109375772337012736  https://fediscience.org/users/macaskillaf/stat...
# 24      109375772337012736  https://fediscience.org/users/macaskillaf/stat...
#
#     replies_count  reblogs_count  favourites_count  \
# 20            1.0            0.0               2.0
# 21            1.0            0.0               1.0
# 22            0.0            0.0               0.0
# 23            1.0            0.0               2.0
# 24            1.0            0.0               0.0
#
#                                               content  \
# 20  <p><span class="h-card"><a href="https://scien...
# 21  <p><span class="h-card"><a href="https://scien...
# 22  <p><span class="h-card"><a href="https://masto...
# 23  <p><span class="h-card"><a href="https://masto...
# 24  <p><span class="h-card"><a href="https://masto...
#
#                   mastodon_name
# 20  macaskillaf@fediscience.org
# 21  macaskillaf@fediscience.org
# 22  macaskillaf@fediscience.org
# 23  macaskillaf@fediscience.org
# 24  macaskillaf@fediscience.org

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
from util import get_instance_token


mentions = []
for idx, row in data.iterrows():
    toot_id = row['id']
    toot_uri = row['uri']
    toot_content = row['content']
    toot_author = row['mastodon_name']
    if type(toot_content) == str:
        soup = BeautifulSoup(toot_content, 'html.parser')
        mentions_list = soup.find_all("a", {"class": "u-url mention"})
    else:
        mentions_list = [{'href':toot_author}]

    for item in mentions_list:
        mentioned = item['href']
        mentions.append(tuple((toot_author, mentioned, toot_id, toot_uri, toot_content)))

mentions = pd.DataFrame(mentions, columns=['toot_author', 'mentioned_user', 'toot_id', 'uri', 'content'])

# %%
mentions.head()
# Out:
#                    toot_author                               mentioned_user  \
# 0  macaskillaf@fediscience.org  https://sciencemastodon.com/@nicoleacrowley
# 1  macaskillaf@fediscience.org         https://mastodon.world/@neuralengine
# 2  macaskillaf@fediscience.org         https://mastodon.social/@NicoleCRust
# 3  macaskillaf@fediscience.org  https://sciencemastodon.com/@nicoleacrowley
# 4  macaskillaf@fediscience.org         https://mastodon.world/@neuralengine
#
#               toot_id                                                uri  \
# 0  109381844602271088  https://fediscience.org/users/macaskillaf/stat...
# 1  109381844602271088  https://fediscience.org/users/macaskillaf/stat...
# 2  109381844602271088  https://fediscience.org/users/macaskillaf/stat...
# 3  109381841933547984  https://fediscience.org/users/macaskillaf/stat...
# 4  109381841933547984  https://fediscience.org/users/macaskillaf/stat...
#
#                                              content
# 0  <p><span class="h-card"><a href="https://scien...
# 1  <p><span class="h-card"><a href="https://scien...
# 2  <p><span class="h-card"><a href="https://scien...
# 3  <p><span class="h-card"><a href="https://scien...
# 4  <p><span class="h-card"><a href="https://scien...

# %%
from util import get_instance_token
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import json

session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

def get_userid(user_instance, user_server):
    try:
        token_access = get_instance_token(user_server)
        url = 'https://{}/api/v1/accounts/lookup/'.format(user_server)
        headers = {
            'Authorization' : 'Bearer {}'.format(token_access)
        }
        params = {
            'acct' : user_instance
        }
        r = session.get(url, headers=headers, params=params)

        user = json.loads(r.text)
        if 'id' in user:
            return user["id"]
        elif 'user' in user:
            return user["user"]
    except Exception as error:
        print(error)
        return None

mentioned_id = []
rename = []
for idx, row in mentions.iterrows():
    try:
        #
        if instance_user.startswith("https"):
            instance_user = row['mentioned_user'][8:].split('/@')
        else:
            instance_user = row['mentioned_user'].split("@")
        
        instance = instance_user[0]
        user = instance_user[1] 
        user_id = get_userid(user, instance)
        name = "{}@{}".format(user, instance)
    except:
        user_id = None
        name = None
        print(row)
    mentioned_id.append(user_id)
    rename.append(name)
mentions['mentioned_id'] = mentioned_id
mentions['mentioned_user_instance'] = rename
mentions.to_csv('kuni_users_mentions.tsv', sep='\t')
# Out:
# toot_author                             macaskillaf@fediscience.org
# mentioned_user                 https://beta.birdsite.live/users/ucl
# toot_id                                          109327340714261792
# uri               https://fediscience.org/users/macaskillaf/stat...
# content           <p><span class="h-card"><a href="https://genom...
# Name: 18, dtype: object
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# toot_author                                danaujoks@mastodon.world
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          110684171350054704
# uri               https://mastodon.world/users/danaujoks/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 179, dtype: object
# toot_author                                danaujoks@mastodon.world
# mentioned_user                  https://a.gup.pe/u/politicalscience
# toot_id                                          110656566608119808
# uri               https://mastodon.world/users/danaujoks/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 185, dtype: object
# toot_author                                danaujoks@mastodon.world
# mentioned_user                         https://a.gup.pe/u/sociology
# toot_id                                          110656566608119808
# uri               https://mastodon.world/users/danaujoks/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 186, dtype: object
# toot_author                                danaujoks@mastodon.world
# mentioned_user                         https://a.gup.pe/u/sociology
# toot_id                                          110205000414286240
# uri               https://mastodon.world/users/danaujoks/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 190, dtype: object
# toot_author                                danaujoks@mastodon.world
# mentioned_user                         https://a.gup.pe/u/sociology
# toot_id                                          109734525819427984
# uri               https://mastodon.world/users/danaujoks/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 196, dtype: object
# toot_author                                danaujoks@mastodon.world
# mentioned_user                  https://a.gup.pe/u/politicalscience
# toot_id                                          109733185010519280
# uri               https://mastodon.world/users/danaujoks/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 198, dtype: object
# toot_author                                 bakerdh@fediscience.org
# mentioned_user                            https://a.gup.pe/u/rstats
# toot_id                                          109876236058997840
# uri               https://fediscience.org/users/bakerdh/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 227, dtype: object
# toot_author                                     VeraK@mastodon.scot
# mentioned_user            https://a.gup.pe/u/collectiveintelligence
# toot_id                                          109426529024901792
# uri               https://mastodon.scot/users/VeraK/statuses/109...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 276, dtype: object
# toot_author                                     VeraK@mastodon.scot
# mentioned_user            https://a.gup.pe/u/collectiveintelligence
# toot_id                                          109426085366407200
# uri               https://mastodon.scot/users/VeraK/statuses/109...
# content           <p>This was an excellent talk with a great out...
# Name: 280, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109658672828653424
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 332, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109658642878775040
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 335, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109658597014209728
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 338, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109642677501374720
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://sauro...
# Name: 341, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109642618847257248
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://sauro...
# Name: 344, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109642577304988000
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://sauro...
# Name: 347, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109559375373049424
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://schol...
# Name: 358, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109559215710140944
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://schol...
# Name: 361, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109559164504971856
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://schol...
# Name: 364, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109559116461900768
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://maths...
# Name: 370, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109559024604606432
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://maths...
# Name: 376, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109559009347528448
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://maths...
# Name: 382, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109558438014405088
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 389, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109558146732413600
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://maths...
# Name: 395, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109558135171078992
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://lingo...
# Name: 401, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109558117136097600
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://lingo...
# Name: 407, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109558087480672144
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 414, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557993255467744
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 422, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557959907956288
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 428, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557890228978976
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 435, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557826138790928
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 441, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557796238898784
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 447, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557768256245344
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 453, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109557731993653312
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 458, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109523039431713008
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://berse...
# Name: 465, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109523018691339136
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://berse...
# Name: 467, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109523008357863024
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://berse...
# Name: 469, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109506403124450304
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://vis.s...
# Name: 473, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109502154856585600
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://vis.s...
# Name: 476, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109451498664769152
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://fedis...
# Name: 486, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109450993392481632
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://ruhr....
# Name: 489, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109450238275276800
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 493, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                     https://a.gup.pe/u/academiamemes
# toot_id                                          109450238275276800
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 494, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user               https://a.gup.pe/u/wahandisifoundation
# toot_id                                          109450238275276800
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 495, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                           https://a.gup.pe/u/wakenya
# toot_id                                          109450238275276800
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 496, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                https://a.gup.pe/u/africanresearchers
# toot_id                                          109450238275276800
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 497, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109449485085055456
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://maths...
# Name: 501, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109449184041806032
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://maths...
# Name: 505, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109449140006831296
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://fedis...
# Name: 509, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109449118304926688
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://dhub....
# Name: 512, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109449029438430496
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 515, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109449005455978640
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://scico...
# Name: 518, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109440664383961120
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://qoto....
# Name: 522, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109440610010783296
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://qoto....
# Name: 526, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109440154765911264
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://dhub....
# Name: 529, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439991304691792
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://astro...
# Name: 532, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439982510919840
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://dhub....
# Name: 535, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439839375482112
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://dhub....
# Name: 537, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439834367181968
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://dhub....
# Name: 539, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439588729681696
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://socia...
# Name: 542, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439550791975424
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 546, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                   https://a.gup.pe/u/academicchatter
# toot_id                                          109439511898191888
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://fedis...
# Name: 548, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user          https://social.mjd.id.au/profile/trregeagle
# toot_id                                          109411766911835360
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://socia...
# Name: 555, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user          https://social.mjd.id.au/profile/trregeagle
# toot_id                                          109411761963378576
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://socia...
# Name: 556, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user          https://social.mjd.id.au/profile/trregeagle
# toot_id                                          109400033040219632
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://socia...
# Name: 559, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user          https://social.mjd.id.au/profile/trregeagle
# toot_id                                          109400014013182480
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://socia...
# Name: 560, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                    https://pixelfed.de/mybirdgallery
# toot_id                                          109297573444325088
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://pixel...
# Name: 613, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user    https://scholar.social/about/more?instance_act...
# toot_id                                          109253483336084608
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 686, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                        https://pixey.org/Bomengidsnl
# toot_id                                          109251980798475712
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://pixey...
# Name: 696, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user             https://gleasonator.com/users/Hyolobrika
# toot_id                                          109246954177263344
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://gleas...
# Name: 706, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                    https://cyrix.matto.nl/users/linm
# toot_id                                          109246941204961632
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://cyrix...
# Name: 707, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user             https://gleasonator.com/users/Hyolobrika
# toot_id                                          109246702213192080
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://gleas...
# Name: 712, dtype: object
# toot_author                                 dr_norb@fediscience.org
# mentioned_user                            https://a.gup.pe/u/plants
# toot_id                                          109159944375125424
# uri               https://fediscience.org/users/dr_norb/statuses...
# content           <p><span class="h-card"><a href="https://masto...
# Name: 723, dtype: object
# Expecting value: line 1 column 1 (char 0)
# toot_author                            niklashoehne@mastodon.social
# mentioned_user    https://tweetbridge.kogasa.de/users/fridayforf...
# toot_id                                          109782986770838880
# uri               https://mastodon.social/users/niklashoehne/sta...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 1081, dtype: object
# toot_author                                dgolumbia@mastodon.world
# mentioned_user                       https://snowdin.town/users/ep1
# toot_id                                          109863527527663904
# uri               https://mastodon.world/users/dgolumbia/statuse...
# content           <p><span class="h-card" translate="no"><a href...
# Name: 1184, dtype: object
# HTTPSConnectionPool(host='spore.social', port=443): Max retries exceeded with url: /api/v1/accounts/lookup/?acct=costrike (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_read_bytes', 'tlsv1 unrecognized name')])")))

# %%
# Out:
# 42244
