# %%
import openai
import numpy as np
import igraph as ig
import pandas as pd
import xnetwork as xnet
from datetime import date
from bs4 import BeautifulSoup

# %%
profiles = pd.read_csv('mentioned_profiles_kuni_2023-08-07 01:20:19.437081.tsv', sep='\t')
print(profiles.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'username', 'acct', 'display_name', 'locked', 'bot',
#        'discoverable', 'group', 'created_at', 'note', 'url', 'avatar',
#        'avatar_static', 'header', 'header_static', 'followers_count',
#        'following_count', 'statuses_count', 'last_status_at', 'noindex',
#        'emojis', 'roles', 'fields', 'uri', 'moved', 'error', 'limited',
#        'suspended'],
#       dtype='object')

# %%
notes = profiles[['username', 'note']]
notes = notes.fillna('')
concepts = pd.read_csv('OpenAlex concepts in use (17 August 2022) - concepts.tsv', sep='\t')
concepts_lvl = concepts[concepts['level'] < 2]

count = 0
concepts_lvl = concepts_lvl['normalized_name'].dropna().values
mentions_concepts = []
for idx, row in notes.iterrows():
    description = BeautifulSoup(row['note']).text.lower()
    scholar_interests = []
    for concept in concepts_lvl:
        if concept in description:
            scholar_interests.append(concept)
    if len(scholar_interests) > 0:
        count += 1
    mentions_concepts.append(scholar_interests)
print(count, len(mentions_concepts))
# Out:
# 1112 2959

# %%
concepts_map = dict()

concepts_lvl = concepts[concepts['level'] < 2]
for idx, row in concepts_lvl.iterrows():
    if row['level'] == 1:
        concepts_map[row['normalized_name']] = row['parent_display_names'].lower().split(', ')
    else:
        concepts_map[row['normalized_name']] = [row['normalized_name']]

# %%
new_name_concepts = []
for items in mentions_concepts:
    new_name = []
    for item in items:
        new_name += concepts_map[item]
    if len(new_name) > 0:
        new_name_concepts.append(max(new_name))
    else:
        new_name_concepts.append('unknown')

# %%
profiles['x_concepts'] = new_name_concepts

# %%
profiles = profiles[['username', 'display_name', 'followers_count', 'following_count', 'url', 'x_concepts']]

# %%
profiles.head()
# Out:
#         username          display_name  followers_count  following_count  \
# 0     mickeykats          Mikhail Kats            321.0             97.0
# 1           josh            Josh Wells           1871.0            786.0
# 2      GuyBirkin            Guy Birkin            626.0            358.0
# 3  Maurice_vTgln  Maurice van Tiggelen            183.0             42.0
# 4     bnlawrence        Bryan Lawrence            577.0            472.0
#
#                                       url x_concepts
# 0      https://mathstodon.xyz/@mickeykats    physics
# 1           https://fediscience.org/@josh  sociology
# 2        https://post.lurk.org/@GuyBirkin        art
# 3  https://fediscience.org/@Maurice_vTgln    physics
# 4         https://mastodon.nz/@bnlawrence    unknown

# %%
profiles = profiles.dropna(subset='username')

# %%
def get_instance(row):
    return "{}".format(row['url'][len("https://"):].split('/')[0])
    
def get_mastodon_name(row):
    instance = get_instance(row)
    return "{}@{}".format(row['username'], instance)

profiles['mastodon_name'] = profiles.apply(get_mastodon_name, axis=1)
profiles['instance'] = profiles.apply(get_instance, axis=1)

# %%
profiles.head()
# Out:
#         username          display_name  followers_count  following_count  \
# 0     mickeykats          Mikhail Kats            321.0             97.0
# 1           josh            Josh Wells           1871.0            786.0
# 2      GuyBirkin            Guy Birkin            626.0            358.0
# 3  Maurice_vTgln  Maurice van Tiggelen            183.0             42.0
# 4     bnlawrence        Bryan Lawrence            577.0            472.0
#
#                                       url x_concepts  \
# 0      https://mathstodon.xyz/@mickeykats    physics
# 1           https://fediscience.org/@josh  sociology
# 2        https://post.lurk.org/@GuyBirkin        art
# 3  https://fediscience.org/@Maurice_vTgln    physics
# 4         https://mastodon.nz/@bnlawrence    unknown
#
#                    mastodon_name         instance
# 0      mickeykats@mathstodon.xyz   mathstodon.xyz
# 1           josh@fediscience.org  fediscience.org
# 2        GuyBirkin@post.lurk.org    post.lurk.org
# 3  Maurice_vTgln@fediscience.org  fediscience.org
# 4         bnlawrence@mastodon.nz      mastodon.nz

# %%
mentions = pd.read_csv('kuni_users_mentions.tsv', sep='\t')

# %%
pairs = mentions[['toot_author', 'mentioned_user_instance']]
pairs.values
# Out:
# array([['macaskillaf@fediscience.org',
#         'nicoleacrowley@sciencemastodon.com'],
#        ['macaskillaf@fediscience.org', 'neuralengine@mastodon.world'],
#        ['macaskillaf@fediscience.org', 'NicoleCRust@mastodon.social'],
#        ...,
#        ['mer__edith@mastodon.world', 'chadloder@kolektiva.social'],
#        ['mer__edith@mastodon.world', 'matthew_d_green@ioc.exchange'],
#        ['mer__edith@mastodon.world', 'matthew_d_green@ioc.exchange']],
#       dtype=object)

# %%
unique = np.unique(pairs.values)

# %%
fields_of_study = pd.read_csv('mastodon_users_wOpenAlex2.csv')[['mastodon_name', 'OpenAlex_account', 'x_concepts']]
fields_of_study['x_concepts'] = fields_of_study['x_concepts'].fillna('unknown')


def edit_mastodon_name(row):
    temp = row['mastodon_name']
    if temp.startswith("@"):
        temp = temp[1:]
    return temp


fields_of_study['mastodon_name'] = fields_of_study.apply(edit_mastodon_name, axis=1)

# %%
fields_of_study.head()
# Out:
#                    mastodon_name                  OpenAlex_account  \
# 0  HelmutBuergmann@mstdn.science  https://openalex.org/A2076598371
# 1           boshek@fosstodon.org  https://openalex.org/A2114692991
# 2            DenisDuboule@mas.to   https://openalex.org/A295410851
# 3       paulgkeil@mastodon.world  https://openalex.org/A2061685470
# 4              rider_jon@zirk.us  https://openalex.org/A2646935175
#
#                                           x_concepts
# 0  [{'id': 'https://openalex.org/C86803240', 'wik...
# 1  [{'id': 'https://openalex.org/C86803240', 'wik...
# 2  [{'id': 'https://openalex.org/C54355233', 'wik...
# 3  [{'id': 'https://openalex.org/C15744967', 'wik...
# 4  [{'id': 'https://openalex.org/C142362112', 'wi...

# %%
from ast import literal_eval

def get_concept(row):
    if row['x_concepts'] == 'unknown':
        return 'unknown'
    list_of_concepts = literal_eval(row['x_concepts'])
    concepts = []
    if len(list_of_concepts) == 0:
        return 'unknown'
    else:
        for concept in list_of_concepts:
            if concept['level'] == 0:
                return concept['display_name']

# %%
fields_of_study['x_concepts'] = fields_of_study.apply(get_concept, axis=1)

# %%
fields_of_study['instance'] = fields_of_study.apply(lambda row: row['mastodon_name'].split("@")[1], axis=1)
fields_of_study.head()
# Out:
#                    mastodon_name                  OpenAlex_account  \
# 0  HelmutBuergmann@mstdn.science  https://openalex.org/A2076598371
# 1           boshek@fosstodon.org  https://openalex.org/A2114692991
# 2            DenisDuboule@mas.to   https://openalex.org/A295410851
# 3       paulgkeil@mastodon.world  https://openalex.org/A2061685470
# 4              rider_jon@zirk.us  https://openalex.org/A2646935175
#
#    x_concepts        instance
# 0     Biology   mstdn.science
# 1     Biology   fosstodon.org
# 2     Biology          mas.to
# 3  Psychology  mastodon.world
# 4         Art         zirk.us

# %%
user_profiles = pd.concat([fields_of_study, profiles])

# %%
user_profiles.head(30)
# Out:
#                      mastodon_name                  OpenAlex_account  \
# 0    HelmutBuergmann@mstdn.science  https://openalex.org/A2076598371
# 1             boshek@fosstodon.org  https://openalex.org/A2114692991
# 2              DenisDuboule@mas.to   https://openalex.org/A295410851
# 3         paulgkeil@mastodon.world  https://openalex.org/A2061685470
# 4                rider_jon@zirk.us  https://openalex.org/A2646935175
# 5   magnuspalmblad@fediscience.org  https://openalex.org/A2058370087
# 6    belovedblackram@ecoevo.social  https://openalex.org/A2656009222
# 7         AxelVisel@genomic.social   https://openalex.org/A217167259
# 8            ohara@hcommons.social  https://openalex.org/A2284742525
# 9       tylermorgan@mathstodon.xyz  https://openalex.org/A2293578381
# 10       neilstats@fediscience.org  https://openalex.org/A2576451780
# 11        geomblog@mastodon.social  https://openalex.org/A2090109395
# 12        macartan@sciences.social  https://openalex.org/A2116540548
# 13     emma_cogdev@fediscience.org  https://openalex.org/A2793519306
# 14             connyyu@scicomm.xyz  https://openalex.org/A3178193640
# 15   Yishai_levin@universeodon.com  https://openalex.org/A2146467551
# 16          crablab@mastodon.world  https://openalex.org/A1968274724
# 17     SuzieReichman@mstdn.science  https://openalex.org/A2303186555
# 18          RayGallon@mstdn.social  https://openalex.org/A2889713977
# 19         hannorein@botsin.space.  https://openalex.org/A3042570580
# 20             tfc@hcommons.social  https://openalex.org/A2988744881
# 21      msevilla00@mastodon.social  https://openalex.org/A2430467668
# 22      lilopozzo@mastodon.social.  https://openalex.org/A2083942260
# 23       diffendale@scholar.social  https://openalex.org/A2956353030
# 24    Andre_Mascar@fediscience.org  https://openalex.org/A2785624393
# 25       doug_manuel@fosstodon.org  https://openalex.org/A2140534386
# 26    gabrielamarcu@mastodon.world  https://openalex.org/A3021608235
# 27  michellecimoli@fediscience.org  https://openalex.org/A3161146405
# 28      impractknow@scholar.social  https://openalex.org/A2790529157
# 29           texas@mastodon.online  https://openalex.org/A2270003825
#
#            x_concepts          instance username display_name  \
# 0             Biology     mstdn.science      NaN          NaN
# 1             Biology     fosstodon.org      NaN          NaN
# 2             Biology            mas.to      NaN          NaN
# 3          Psychology    mastodon.world      NaN          NaN
# 4                 Art           zirk.us      NaN          NaN
# 5             Biology   fediscience.org      NaN          NaN
# 6             Biology     ecoevo.social      NaN          NaN
# 7             Biology    genomic.social      NaN          NaN
# 8          Philosophy   hcommons.social      NaN          NaN
# 9          Psychology    mathstodon.xyz      NaN          NaN
# 10         Psychology   fediscience.org      NaN          NaN
# 11        Mathematics   mastodon.social      NaN          NaN
# 12  Political science   sciences.social      NaN          NaN
# 13         Psychology   fediscience.org      NaN          NaN
# 14            Biology       scicomm.xyz      NaN          NaN
# 15           Medicine  universeodon.com      NaN          NaN
# 16        Engineering    mastodon.world      NaN          NaN
# 17            Biology     mstdn.science      NaN          NaN
# 18         Psychology      mstdn.social      NaN          NaN
# 19            Physics     botsin.space.      NaN          NaN
# 20            unknown   hcommons.social      NaN          NaN
# 21          Geography   mastodon.social      NaN          NaN
# 22          Chemistry  mastodon.social.      NaN          NaN
# 23            History    scholar.social      NaN          NaN
# 24  Political science   fediscience.org      NaN          NaN
# 25           Medicine     fosstodon.org      NaN          NaN
# 26         Psychology    mastodon.world      NaN          NaN
# 27         Psychology   fediscience.org      NaN          NaN
# 28         Philosophy    scholar.social      NaN          NaN
# 29         Psychology   mastodon.online      NaN          NaN
#
#     followers_count  following_count  url
# 0               NaN              NaN  NaN
# 1               NaN              NaN  NaN
# 2               NaN              NaN  NaN
# 3               NaN              NaN  NaN
# 4               NaN              NaN  NaN
# 5               NaN              NaN  NaN
# 6               NaN              NaN  NaN
# 7               NaN              NaN  NaN
# 8               NaN              NaN  NaN
# 9               NaN              NaN  NaN
# 10              NaN              NaN  NaN
# 11              NaN              NaN  NaN
# 12              NaN              NaN  NaN
# 13              NaN              NaN  NaN
# 14              NaN              NaN  NaN
# 15              NaN              NaN  NaN
# 16              NaN              NaN  NaN
# 17              NaN              NaN  NaN
# 18              NaN              NaN  NaN
# 19              NaN              NaN  NaN
# 20              NaN              NaN  NaN
# 21              NaN              NaN  NaN
# 22              NaN              NaN  NaN
# 23              NaN              NaN  NaN
# 24              NaN              NaN  NaN
# 25              NaN              NaN  NaN
# 26              NaN              NaN  NaN
# 27              NaN              NaN  NaN
# 28              NaN              NaN  NaN
# 29              NaN              NaN  NaN

# %%
print(len(user_profiles))
user_profiles = user_profiles.drop_duplicates(subset='mastodon_name')
print(len(user_profiles))
# Out:
# 7605
# 5958

# %%
g_mentions = ig.Graph(directed=True)
g_mentions.add_vertices(len(user_profiles))
g_mentions.vs['name'] = user_profiles['mastodon_name'].values

valid_pairs = []
for idx, pair in pairs.iterrows():
    if pair.toot_author in g_mentions.vs['name'] and pair.mentioned_user_instance in g_mentions.vs['name']:
        valid_pairs.append(pair)

# %%
g_mentions.add_edges(valid_pairs)

# %%
g_mentions.vs['instances'] = user_profiles['instance'].values

# %%
g_mentions.vs['concepts'] = concepts

# %%
count
# Out:
# 4621

# %%
xnet.igraph2xnet(g_mentions, 'g_mentions.xnet')
